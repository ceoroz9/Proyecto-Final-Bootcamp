# %% [markdown]
# Hola &#x1F600;
#
# Soy **Hesus Garcia**  como "Jesús" pero con H. Sé que puede ser confuso al principio, pero una vez que lo recuerdes, ¡nunca lo olvidarás! &#x1F31D;	. Como revisor de código de Practicum, estoy emocionado de examinar tus proyectos y ayudarte a mejorar tus habilidades en programación. si has cometido algún error, no te preocupes, pues ¡estoy aquí para ayudarte a corregirlo y hacer que tu código brille! &#x1F31F;. Si encuentro algún detalle en tu código, te lo señalaré para que lo corrijas, ya que mi objetivo es ayudarte a prepararte para un ambiente de trabajo real, donde el líder de tu equipo actuaría de la misma manera. Si no puedes solucionar el problema, te proporcionaré más información en la próxima oportunidad. Cuando encuentres un comentario,  **por favor, no los muevas, no los modifiques ni los borres**.
#
# Revisaré cuidadosamente todas las implementaciones que has realizado para cumplir con los requisitos y te proporcionaré mis comentarios de la siguiente manera:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# </br>
#
# **¡Empecemos!**  &#x1F680;

# %% [markdown]
# # Descomposición
#
# Estudiante: César Orozco
#
# &nbsp;
#
# - **Introducción**
# - Descripción de los datos
#
# &nbsp;
#
# - **Paso 1**. Descarga de los datos y preparacion para el análisis.
#   Almacenar los datos en operadores, y clientes en variables. Optimizar los datos para el análisis. Asegurarse de que cada columna contiene el tipo de datos correcto.
#
# &nbsp;
#
# - **Paso 2**. Preprocesamiento de los datos:
# - Convertir tipos
# - Comprobar que los nombres de las columnas son correctos
# - Cambiar el nombre de las columnas (tamaño, espacios y título real)
# - Estudiar los valores que faltan
# - Estudiar valor incorrecto
#   - duración_llamada_total < duración_llamada
#   - duración_llamada > 0 is_missed_call = True
# - Estudiar los valores duplicados
#   (intentar identificar la razón de la aparición de duplicados)
# - Eliminar duplicados
# - Recuperar los datos que faltan y los introducidos incorrectamente.
#
# &nbsp;
#
# - **Paso 3**. Análisis exploratorio de datos.
# - Valores atípicos: - Construir gráficos para determinar los valores atípicos
#   - Duración de la llamada > 8(6) horas (duración_llamada / duración_llamada_total)
#   - Duración de la llamada < 3 segundos
#   - Número de llamadas (calls_count)
#   - Fecha - Definir los umbrales. Explicar por qué se ha elegido este método concreto y cómo se han determinado los umbrales. -  - Eliminar los valores atípicos
# - ¿Cuántos clientes utilizan este servicio?
# - Trazar distribuciones de tarifas entre clientes por mes.
# - Trazar distribuciones del número de operadores por clientes.
# - Distribución del número de llamadas por día/mes.
# - Trazar distribuciones de la duración de las llamadas por días / meses / por clientes.
# - Estudiar la proporción de llamadas internas/externas (para cada plan de tarifas).
# - Estudiar la cuota de llamadas entrantes/salientes (para cada plan de tarifas). ¿Notas algo?
# - Estudiar el porcentaje de llamadas perdidas de los clientes.
# - ¿Quizás algunas empresas no tienen suficientes operadores y por eso el porcentaje de llamadas perdidas es alto?
# - ¿Cuánto tiempo esperan los clientes una respuesta? (media diaria por empresas)
#
# &nbsp;
#
# - **Paso 4**. Dividir a los operadores en eficaces/no eficaces
# - Dividir a los operadores en tipos:
#   -   Tipo A. Sólo llamadas entrantes
#   -   Tipo B. Sólo llamadas salientes
#   -   Tipo C. Tanto entrantes como salientes (general).
# - Trazar la distribución de los tipos de operadores por clientes.
# - Estudiar las características que permiten evaluar la eficacia del operador:
#   - Distribución gráfica del número de llamadas salientes para el operador de tipo B.
#   - Trazar distribuciones de la duración de las llamadas salientes para el operador de tipo B.
#   - Distribuciones gráficas de las llamadas entrantes para los operadores de tipo A y C.
#   - Distribución gráfica del tiempo de espera para los operadores de tipo A y C.
#   - Proporción de llamadas perdidas/entrantes para los operadores de tipo C.
# - Punto X. Definir los umbrales de operador efectivo/inefectivo para cada tipo.
# - Criterio de operador ineficaz.
#   - Tipo A: El número de llamadas perdidas o el tiempo de espera es superior al establecido en el punto X. También hay que estimar la duración de las llamadas realizadas.
#   - Tipo B: La duración o el número de llamadas es inferior a lo establecido en el punto X.
#   - Tipo C: Para cada operador, los umbrales (número de llamadas perdidas o tiempo de espera) se definirán individualmente en función del número de llamadas salientes. Es posible que un operador tenga malos indicadores en cuanto a tiempo de espera y número de llamadas perdidas, pero un excelente indicador de llamadas salientes. En este caso, no se puede llamar al operador ineficaz, pero es necesario informar al cliente de que el desvío está mal configurado o no hay suficientes operadores. Y es necesario aconsejar al cliente que asigne operadores adicionales a las llamadas entrantes de los clientes.
# - Asignar una calificación al operador. (efectivo/inefectivo)
# - Trazar las distribuciones de la empresa según la proporción de operadores ineficaces (incluso con un desglose por tipo de tarifa).
#
# &nbsp;
#
# - **Paso 5**. Probar las siguientes hipótesis:
# - Cuantas más llamadas tengan los operadores al día, más llamadas perdidas tendrá.
# - Cuantos menos operadores tiene un cliente, más llamadas perdidas tiene.
# - Los operadores que realizan tanto llamadas entrantes como salientes tienen más llamadas perdidas que los operadores que sólo realizan llamadas entrantes.
# - El porcentaje de llamadas perdidas los fines de semana es mayor que entre semana. (Si se confirma esta hipótesis, significa que no hay suficientes operadores trabajando los fines de semana).
#
# &nbsp;
#
# - **Paso 6**. Predicción
# - Realizar un análisis exploratorio de los datos
#   - Comparar los valores medios de las características en dos grupos
#   - Trazar distribuciones de características entre dos tipos de operadores.
#   - Matriz de correlación entre las características de los operadores
# - Crear agrupaciones de operadores
#   - Normalizar los datos y trazar un dendrograma
#   - Divida los datos en conjuntos de entrenamiento y validación.
#   - Entrenar el modelo en el conjunto de entrenamiento con el algoritmo "K-means".
#   - Los valores medios de las características de los conglomerados.
#   - Trazar las distribuciones de características para los clusters.
#   - Calcular el coeficiente de eficiencia de cada clúster.
# - Conclusión
#
# &nbsp;
# - **Conclusiones y recomendaciones básicas**
#   - Redactar una conclusión general.
#   - Recomendaciones.
# - Presentación

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Comentario del Revisor</b>
# <p>Hola Cesar,</p>
# <p>He revisado tu propuesta de proyecto final y me complace ver que tienes una estructura clara y un enfoque bien definido para tu análisis. A continuación, te ofrezco algunos comentarios y sugerencias para mejorar tu proyecto:</p>
# <ul>
# <li><b>Definición de Objetivos:</b> Tu objetivo está claramente definido, lo cual es fundamental para un análisis exitoso. Sin embargo, te recomendaría especificar aún más qué significa ser un "operador ineficaz" desde un punto de vista estadístico y empresarial. Esto podría incluir parámetros específicos como el porcentaje de llamadas perdidas, la duración promedio de las llamadas y los tiempos de espera.</li>
# <li><b>Análisis de Hipótesis:</b> Tus hipótesis son relevantes y bien planteadas. Sería beneficioso establecer criterios cuantitativos claros para evaluar estas hipótesis. Por ejemplo, define qué se considera un "tiempo de espera prolongado" o un "alto número de llamadas perdidas".</li>
# <li><b>Manejo de Tipos de Datos:</b> Asegúrate de especificar y convertir adecuadamente los tipos de datos, especialmente las fechas y las categorías. Esto es crucial para un análisis eficiente y para evitar errores comunes en el procesamiento de datos.</li>
# <li><b>Visualización de Datos:</b> Has elegido herramientas adecuadas para la visualización. Considera incluir visualizaciones interactivas, como gráficos de dispersión o mapas de calor, para analizar la relación entre diferentes variables.</li>
#
# </ul>
#
# </div>
